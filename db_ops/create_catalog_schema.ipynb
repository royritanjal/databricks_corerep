# %%
# %sql
CREATE CATALOG IF NOT EXISTS raw_data
COMMENT 'Catalog for raw data for CoreRep';

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS raw_data.corerep
COMMENT 'Finance-related curated datasets';

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS corerep.reference_data
COMMENT 'Reference data for Finance';
